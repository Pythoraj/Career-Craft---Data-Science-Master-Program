# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("IPL2023_Batsman.csv", encoding_errors='ignore')

# %%
df
# Out:
#       match_no          Batsman                 team  Run  Ball  4s  6s  \
# 0            1     Devon Conway  Chennai Super Kings    1     6   0   0
# 1            1  Ruturaj Gaikwad  Chennai Super Kings   92    50   4   9
# 2            1        Moeen Ali  Chennai Super Kings   23    17   4   1
# 3            1       Ben Stokes  Chennai Super Kings    7     6   1   0
# 4            1    Ambati Rayudu  Chennai Super Kings   12    12   0   1
# ...        ...              ...                  ...  ...   ...  ..  ..
# 1109        70     Shubman Gill       Gujarat Titans  104    52   5   8
# 1110        70    Vijay Shankar       Gujarat Titans   53    35   7   2
# 1111        70    Dasun Shanaka       Gujarat Titans    0     3   0   0
# 1112        70     David Miller       Gujarat Titans    6     7   1   0
# 1113        70    Rahul Tewatia       Gujarat Titans    4     5   0   0
#
#                  out_by
# 0        Mohammed Shami
# 1        Alzarri Joseph
# 2           Rashid Khan
# ...

# %%
#bar plot >> To see the distribution of categorical variables
#bar plot uses rectangular bars to compare several categories or groupings if data.
#the height of the bar plot corresponds to the amount of data it represents

x = ["CSK", "GT", "RR", "RCB"]
y = [100, 90, 110, 80]

plt.bar(x, y, color='r')
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(x, y, color='r')
# Out:
# <BarContainer object of 4 artists>

# %%
#problem statement, how many numbers of 4s and 6s is hit by each team

# %%
df
# Out:
#       match_no          Batsman                 team  Run  Ball  4s  6s  \
# 0            1     Devon Conway  Chennai Super Kings    1     6   0   0
# 1            1  Ruturaj Gaikwad  Chennai Super Kings   92    50   4   9
# 2            1        Moeen Ali  Chennai Super Kings   23    17   4   1
# 3            1       Ben Stokes  Chennai Super Kings    7     6   1   0
# 4            1    Ambati Rayudu  Chennai Super Kings   12    12   0   1
# ...        ...              ...                  ...  ...   ...  ..  ..
# 1109        70     Shubman Gill       Gujarat Titans  104    52   5   8
# 1110        70    Vijay Shankar       Gujarat Titans   53    35   7   2
# 1111        70    Dasun Shanaka       Gujarat Titans    0     3   0   0
# 1112        70     David Miller       Gujarat Titans    6     7   1   0
# 1113        70    Rahul Tewatia       Gujarat Titans    4     5   0   0
#
#                  out_by
# 0        Mohammed Shami
# 1        Alzarri Joseph
# 2           Rashid Khan
# ...

# %%
df['boundaries_no'] = df["4s"]+df["6s"]

# %%
df
# Out:
#       match_no          Batsman                 team  Run  Ball  4s  6s  \
# 0            1     Devon Conway  Chennai Super Kings    1     6   0   0
# 1            1  Ruturaj Gaikwad  Chennai Super Kings   92    50   4   9
# 2            1        Moeen Ali  Chennai Super Kings   23    17   4   1
# 3            1       Ben Stokes  Chennai Super Kings    7     6   1   0
# 4            1    Ambati Rayudu  Chennai Super Kings   12    12   0   1
# ...        ...              ...                  ...  ...   ...  ..  ..
# 1109        70     Shubman Gill       Gujarat Titans  104    52   5   8
# 1110        70    Vijay Shankar       Gujarat Titans   53    35   7   2
# 1111        70    Dasun Shanaka       Gujarat Titans    0     3   0   0
# 1112        70     David Miller       Gujarat Titans    6     7   1   0
# 1113        70    Rahul Tewatia       Gujarat Titans    4     5   0   0
#
#                  out_by  boundaries_no
# 0        Mohammed Shami              0
# ...

# %%
#based on boundaries

boundaries = df.groupby("team")["boundaries_no"].sum()

plt.figure(figsize=(10, 6))

boundaries.plot(kind="bar", figsize=(10, 6))
plt.show()

# %%
#individual 4 and 6

boundaries = df.groupby("team")[["4s", "6s"]].sum()

plt.figure(figsize=(10, 6))

boundaries.plot(kind="bar", figsize=(10, 6))
plt.show()

# %%
#who are top 10 run scorers?
top_batsman = df.groupby('Batsman')["Run"].sum().sort_values(ascending=False).head(10)
top_batsman.plot(kind = 'barh', color = "orange", edgecolor = 'black')
plt.title("Top 10 run scorers")
plt.xlabel("Runs")
plt.ylabel("Batsman")
plt.show()

# %%
df
# Out:
#       match_no          Batsman                 team  Run  Ball  4s  6s  \
# 0            1     Devon Conway  Chennai Super Kings    1     6   0   0
# 1            1  Ruturaj Gaikwad  Chennai Super Kings   92    50   4   9
# 2            1        Moeen Ali  Chennai Super Kings   23    17   4   1
# 3            1       Ben Stokes  Chennai Super Kings    7     6   1   0
# 4            1    Ambati Rayudu  Chennai Super Kings   12    12   0   1
# ...        ...              ...                  ...  ...   ...  ..  ..
# 1109        70     Shubman Gill       Gujarat Titans  104    52   5   8
# 1110        70    Vijay Shankar       Gujarat Titans   53    35   7   2
# 1111        70    Dasun Shanaka       Gujarat Titans    0     3   0   0
# 1112        70     David Miller       Gujarat Titans    6     7   1   0
# 1113        70    Rahul Tewatia       Gujarat Titans    4     5   0   0
#
#                  out_by  boundaries_no
# 0        Mohammed Shami              0
# ...

# %%
#how many runs were scored in each match?

match_runs = df.groupby("match_no")["Run"].sum()
plt.figure(figsize=(12,5))
match_runs.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title("Total Runs Scored in Each Match")
plt.xlabel("Match Number")
plt.ylabel("Total Runs")
plt.xticks(rotation=45)
plt.show()

# %%
#who has hit the more sixes -top 10 player?

top_six_hitters = df.groupby("Batsman")["6s"].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(10,6))
top_six_hitters.plot(kind='bar', color='red', edgecolor='black')
plt.title("Top 10 Six-Hitters in IPL")
plt.xlabel("Batsman")
plt.ylabel("Total Sixes")
plt.xticks(rotation=45)
plt.show()

# %%
x = ["CSK", "GT", "RR", "RCB"]
y = [100, 90, 110, 80]

plt.bar(x, y, color='r')
plt.xlabel("Name of teams")
plt.ylabel("Scores")
plt.show()

# %%
#making bar plot more beautiful

x = ["CSK", "GT", "RR", "RCB"]
y = [100, 90, 110, 80]

plt.bar(x, y, color='r', width = 0.25, align="edge", edgecolor = "g", linewidth=3, alpha=1, linestyle = "--") #align equals to edge means, starting the bar after the tick and name on xaxis
plt.xlabel("Name of teams")
plt.ylabel("Scores")
plt.show()

# %%
#making bar plot more beautiful

x = ["CSK", "GT", "RR", "RCB"]
y = [100, 90, 110, 80]

plt.barh(x, y, color='r', align="edge", edgecolor = "g", linewidth=3, alpha=1, linestyle = "--") #align equals to edge means, starting the bar after the tick and name on xaxis
plt.xlabel("Name of teams")
plt.ylabel("Scores")
plt.show()

# %%
df
# Out:
#       match_no          Batsman                 team  Run  Ball  4s  6s  \
# 0            1     Devon Conway  Chennai Super Kings    1     6   0   0
# 1            1  Ruturaj Gaikwad  Chennai Super Kings   92    50   4   9
# 2            1        Moeen Ali  Chennai Super Kings   23    17   4   1
# 3            1       Ben Stokes  Chennai Super Kings    7     6   1   0
# 4            1    Ambati Rayudu  Chennai Super Kings   12    12   0   1
# ...        ...              ...                  ...  ...   ...  ..  ..
# 1109        70     Shubman Gill       Gujarat Titans  104    52   5   8
# 1110        70    Vijay Shankar       Gujarat Titans   53    35   7   2
# 1111        70    Dasun Shanaka       Gujarat Titans    0     3   0   0
# 1112        70     David Miller       Gujarat Titans    6     7   1   0
# 1113        70    Rahul Tewatia       Gujarat Titans    4     5   0   0
#
#                  out_by  boundaries_no
# 0        Mohammed Shami              0
# ...

# %%
#make a plot for the top 5 batsman(in terms of runs), with balls, runs, 4s and 6s in the bar plot?


stats = df.groupby("Batsman")[["Ball", "4s", "6s", "Run"]].sum()

top_5_batsmen = stats.nlargest(5, "Run") #nlargest>> highest values
 
plt.figure(figsize=(10, 6))

top_5_batsmen.plot(kind="bar", figsize=(10, 6))
# Out:
# <Axes: xlabel='Batsman'>

# %%
#Histogram
#for continuous numerical data
#it counts the no of data points that fall into each bin/interval of range of values
#univariate analysis

# %%
data = np.random.normal(0, 1, 1000)
data
# Out:
# array([ 8.21038537e-01,  3.24192992e-02,  9.50650675e-01, -2.49523542e+00,
#         2.19174755e-01,  4.72452855e-01,  6.74184404e-01,  5.75650686e-01,
#         9.50801707e-01, -7.39613581e-01, -1.25079660e+00, -7.78870636e-01,
#        -7.07598445e-01,  7.64512320e-01, -2.98664730e-01, -1.55363224e+00,
#        -2.08241611e-01, -1.17632297e+00,  1.39950143e+00, -5.60769158e-01,
#        -8.23086058e-01,  2.65538654e+00, -3.88334224e-01,  6.60058518e-02,
#        -6.52162781e-01, -4.21777324e-01, -4.10112380e-01,  1.75422517e+00,
#         3.42393534e-01, -1.62311109e+00,  4.59821279e-01, -1.64014633e+00,
#        -1.22829994e+00, -1.25957237e+00, -2.28983874e+00,  5.98405839e-01,
#         1.22177062e+00,  2.01153972e-01, -4.41988682e-01,  8.29613103e-01,
#         1.83930753e+00, -1.75056511e-02, -7.65017719e-02,  7.80735581e-03,
#         9.55171826e-01, -8.94598177e-02, -5.25789176e-02, -4.03526609e-01,
# ...

# %%
plt.hist(data, color = 'y',bins=20, edgecolor = 'g') #default bins is 10
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Histogram plot")
plt.show()

# %%
#find the six hitting ability of rohit sharma and virat kohli


df_kohli = df[df["Batsman"] == "Virat Kohli"]
df_rohit = df[df["Batsman"] == "Rohit Sharma"]

plt.figure(figsize=(8,5))
plt.hist(df_kohli["6s"], bins=5, alpha=0.5, label="Virat Kohli", color="blue")
plt.hist(df_rohit["6s"], bins=5, alpha=0.5, label="Rohit Sharma", color="red")
plt.title("Number of Sixes Per Match - Kohli vs Rohit")
plt.xlabel("Number of Sixes")
plt.ylabel("Frequency")
plt.legend()
plt.show()

# %%
#internal homeworks>> make a stacked bar chart for the above questions

# %%
df_rohit
# Out:
#       match_no       Batsman            team  Run  Ball  4s  6s  \
# 68           5  Rohit Sharma  Mumbai Indians    1    10   0   0
# 185         12  Rohit Sharma  Mumbai Indians   21    13   3   1
# 245         16  Rohit Sharma  Mumbai Indians   65    45   6   4
# 356         22  Rohit Sharma  Mumbai Indians   20    13   1   2
# 398         25  Rohit Sharma  Mumbai Indians   28    18   6   0
# 505         31  Rohit Sharma  Mumbai Indians   44    27   4   3
# 575         35  Rohit Sharma  Mumbai Indians    2     8   0   0
# 687         42  Rohit Sharma  Mumbai Indians    3     5   0   0
# 746         46  Rohit Sharma  Mumbai Indians    0     3   0   0
# 789         49  Rohit Sharma  Mumbai Indians    0     3   0   0
# 864         54  Rohit Sharma  Mumbai Indians    7     8   1   0
# 902         57  Rohit Sharma  Mumbai Indians   29    18   3   2
# 1011        63  Rohit Sharma  Mumbai Indians   37    25   1   3
# 1098        69  Rohit Sharma  Mumbai Indians   56    37   8   1
#
# ...

# %%
#stacked histogram
data1 = np.random.normal(0, 1, 1000)
data2 = np.random.normal(3, 1, 1000)

plt.hist([data1, data2], bins=20, color=['skyblue', 'salmon'], edgecolor='black', label=['distribution 1', 'distribution 2'])
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Stacked Histogram")
plt.legend()
plt.show()

# %%
#make an average line in the plot

data = np.random.gamma(2, 1, 100)


plt.hist(data, bins=20, color='green', edgecolor='black', alpha=0.8, density=True)
plt.axvline(data.mean(), color='red', linestyle='dashed', linewidth=1, label='Mean')
plt.xlabel("Value")
plt.ylabel("Probability Density")
plt.title("Customized Histogram")
plt.legend()
plt.show()

# %%
#pie chart > show how categorical data is distributed, percentage share of a categorical variable
#to find the contribution/percent share of each of the categories

# %%
x = ["CSK", "GT", "RR", "RCB"]
y = [100, 90, 11, 80] #Total no of sixes

plt.pie(y, labels = x, autopct = '%1.1f%%')
plt.title("Pie Chart")
plt.show()

# %%
langs = ["Python", "C", "Java"]
students = [980, 400, 100]

plt.pie(students, labels = langs, autopct = '%1.1f%%')
plt.title("Pie Chart")
plt.show()

# %%
#How much of a batsman total runs came from boundaries? Assume the batsman is Virat Kohli


player = "Virat Kohli"

df_player = df[df["Batsman"] == player]
boundary_runs = (df_player["4s"] * 4 + df_player["6s"] * 6).sum()
other_runs = df_player["Run"].sum() - boundary_runs


plt.figure(figsize=(6,6))
plt.pie([boundary_runs, other_runs], labels=["From Boundaries", "Other Runs"], autopct='%1.1f%%', colors=["pink", "green"])
plt.title(f"Percentage of Runs from Boundaries for {player}")
plt.show()

# %%
#internal homework, please try to do it for all the batsman >> simply do it for complete dataframe

# %%
explode = [0.1, 0.01, 0.01]
langs = ["Python", "C", "Java"]
students = [980, 400, 100]

plt.pie(students, labels = langs, autopct = '%1.1f%%', explode=explode, shadow=True, radius=1.5)
plt.title("Pie Chart")
plt.show()

# %%
#Boxplot


data = [-3,1, 2, 3, 1, 2, 5]
plt.boxplot(data)
plt.show()

# %%
#Among rohit sharma and virat kohli who is more consistent in terms of runs?
df_kohli = df[df["Batsman"] == "Virat Kohli"]
df_rohit = df[df["Batsman"] == "Rohit Sharma"]

plt.figure(figsize=(8,5))
plt.boxplot([df_kohli["Run"], df_rohit["Run"]], labels=["Virat Kohli", "Rohit Sharma"], patch_artist=True)
plt.title("Run Distribution - Kohli vs Rohit")
plt.ylabel("Runs Per Match")
plt.show()

#insights>> virat kohli looks more consistent
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_9188\2984909827.py:6: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([df_kohli["Run"], df_rohit["Run"]], labels=["Virat Kohli", "Rohit Sharma"], patch_artist=True)

# %%
plt.violinplot(df_kohli["Run"])
plt.show()

# %%
#Adbvanced matplotlib and plots
import seaborn as sns
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sc = plt.scatter(tips['total_bill'], tips["tip"], c=tips['size'], cmap="jet", alpha=0.8)
plt.xlabel("Total Bill")
plt.ylabel("Tip")
plt.colorbar(sc, label="Table Size")
plt.show()



#various colour map
# 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Grays', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'flare', 'flare_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_grey', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gist_yerg', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'grey', 'hot', 'hot_r', 'hsv', 'hsv_r', 'icefire', 'icefire_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'mako', 'mako_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'rocket', 'rocket_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'vlag', 'vlag_r', 'winter', 'winter_r'

# %%
plt.figure(figsize = (15, 8))

plt.scatter(tips['total_bill'], tips["tip"], c=tips['size'], cmap="jet", alpha=0.8) #Set3 is also a colour map
plt.xlabel("Total bill")
plt.ylabel("tip")
plt.show()

# %%
plt.figure(figsize=(18,10))
plt.scatter(tips['total_bill'], tips['tip'], s=tips['size']*50, alpha=0.6, color="purple")

for i in range(tips.shape[0]):
    plt.text(tips['total_bill'].values[i], tips['tip'].values[i], tips['day'].values[i], fontsize=10)

plt.xlabel("Total Bill Amount ($)")
plt.ylabel("Tip Amount ($)")
plt.title("Total Bill vs. Tip Amount with Table Size Indicated")
plt.show()

# Insights:
# - Larger bubbles indicate larger table sizes, showing how party size influences tipping.
# - Higher total bills generally lead to higher tips, but there are variations.
# - Certain days may have more outliers, indicating inconsistent tipping behavior.

# %%
#drawing a horizontal and vertical lines in the plot

plt.figure(figsize=(18,10))
plt.scatter(tips['total_bill'], tips['tip'], s=tips['size']*50, alpha=0.6, color="purple")

plt.axhline(5, color='red')  # Threshold for tip amount
plt.axhline(10, color='green')  # Higher tip threshold
plt.axvline(20, color='red')  # Threshold for total bill

for i in range(tips.shape[0]):
    plt.text(tips['total_bill'].values[i], tips['tip'].values[i], tips['day'].values[i], fontsize=10)

plt.xlabel("Total Bill Amount ($)")
plt.ylabel("Tip Amount ($)")
plt.title("Total Bill vs. Tip Amount with Table Size Indicated")
plt.show()

# Insights:
# - Red horizontal line at $5 indicates a minimum threshold for tipping behavior.
# - Green horizontal line at $10 represents a higher tip category, possibly linked to generous tipping.
# - Red vertical line at $20 marks the threshold where higher spending may impact tipping habits.
# - Most tips seem to follow an increasing trend with the total bill, though variations exist.

# %%
#multiple subplots

fig, ax = plt.subplots(nrows=2, ncols=1, sharex=True, figsize=(10,6))

ax[0].scatter(tips['total_bill'], tips['tip'], color='red')
ax[1].scatter(tips['total_bill'], tips['size'])

ax[0].set_title('Total Bill vs Tip Amount')
ax[0].set_ylabel('Tip Amount')

ax[1].set_title('Total Bill vs Table Size')
ax[1].set_ylabel('Table Size')
ax[1].set_xlabel('Total Bill Amount')

fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10,10))

ax[0,0].scatter(tips['total_bill'], tips['tip'])
ax[0,1].scatter(tips['total_bill'], tips['size'])
ax[1,0].hist(tips['total_bill'], bins=10, color='blue', edgecolor='black')
ax[1,1].hist(tips['tip'], bins=10, color='green', edgecolor='black')

ax[0,0].set_title('Total Bill vs Tip')
ax[0,1].set_title('Total Bill vs Table Size')
ax[1,0].set_title('Distribution of Total Bill')
ax[1,1].set_title('Distribution of Tip Amount')

plt.tight_layout()
plt.show()

# Insights:
# - The first subplot shows a positive correlation between total bill and tip amount.
# - The second subplot suggests that larger tables tend to have higher total bills.
# - The histogram of total bills is right-skewed, meaning most bills are on the lower side.
# - The histogram of tips suggests that most tips are clustered in the lower range, with fewer high-value tips.

# %%
#3d line plot
x = [0,1,5,25]
y = [0,10,13,0]
z = [0,13,20,9]

fig = plt.figure()

ax = plt.subplot(projection='3d')

ax.scatter3D(x,y,z,s=[100,100,100,100])
ax.plot3D(x,y,z,color='red')

# %%
#3d scatter plots
x = np.random.rand(20)
y = np.random.rand(20)
z = np.random.rand(20)


fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
ax.scatter(x, y, z, c = 'red')

# %%
import numpy as np
import matplotlib.pyplot as plt

ax = plt.figure().add_subplot(projection='3d')

x = np.linspace(0, 1, 100)
y = np.sin(x * 2 * np.pi) / 2 + 0.5
ax.plot(x, y, zs=0, zdir='z', label='curve in (x, y)')


colors = ('r', 'g', 'b', 'k')

np.random.seed(19680801)

x = np.random.sample(20 * len(colors))
y = np.random.sample(20 * len(colors))
c_list = []
for c in colors:
    c_list.extend([c] * 20)

ax.scatter(x, y, zs=0, zdir='y', c=c_list, label='points in (x, z)')

ax.legend()
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.set_zlim(0, 1)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')


ax.view_init(elev=20., azim=-35, roll=0)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt



fig = plt.figure(figsize=(9, 3))
ax1 = fig.add_subplot(121, projection='3d')
ax2 = fig.add_subplot(122, projection='3d')


_x = np.arange(8)
_y = np.arange(9)
_xx, _yy = np.meshgrid(_x, _y)
x, y = _xx.ravel(), _yy.ravel()

top = x + y
bottom = np.zeros_like(top)
width = depth = 1

ax1.bar3d(x, y, bottom, width, depth, top, shade=True)
ax1.set_title('Shaded')

ax2.bar3d(x, y, bottom, width, depth, top, shade=False)
ax2.set_title('Not Shaded')

plt.show()

# %%
#area plot >> stacked area plot
#to show how various quantitative factors have changed over time while highlighting how they all worl together to form whole

import matplotlib.pyplot as plt


years = [2021, 2018, 2024, 2023, 2017]
category1 = [20, 25, 30, 28, 35]
category2 = [10, 15, 20, 18, 25]
category3 = [5, 8, 10, 9, 15]


plt.stackplot(years, category1, category2, category3, labels=['Category 1', 'Category 2', 'Category 3'],
              colors=['skyblue', 'lightgreen', 'orange'])


plt.xlabel("Years")
plt.ylabel("Values")
plt.title("Area Plot")
plt.legend()

plt.show()

# %%
#3d surface plots
x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)

xx, yy = np.meshgrid(x, y)
z = xx**2+yy**2

# Return a tuple of coordinate matrices from coordinate vectors.
# Make N-D coordinate arrays for vectorized evaluations of N-D scalar/vector fields over N-D grids, given one-dimensional coordinate arrays x1, x2,…, xn.

# %%
xx.shape
# Out:
# (100, 100)

# %%
yy.shape
# Out:
# (100, 100)

# %%
z.shape
# Out:
# (100, 100)

# %%
fig = plt.figure(figsize = (12, 10))
ax = plt.subplot(projection = "3d")
p = ax.plot_surface(xx, yy, z, cmap = "viridis")
fig.colorbar(p)

# %%
z = np.sin(xx)+np.cos(yy)
fig = plt.figure(figsize = (12, 10))
ax = plt.subplot(projection = "3d")
p = ax.plot_surface(xx, yy, z, cmap = "viridis")
fig.colorbar(p)

# %%
z = np.sin(xx) + np.log(xx)

fig = plt.figure(figsize=(12,8))

ax = plt.subplot(projection='3d')

p = ax.plot_surface(xx,yy,z,cmap='viridis')
fig.colorbar(p)
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_9188\684431574.py:1: RuntimeWarning: invalid value encountered in log
#   z = np.sin(xx) + np.log(xx)

# %%
#contour plot
z = np.sin(xx) + np.cos(yy)

fig = plt.figure(figsize=(12,8))

ax = plt.subplot()

p = ax.contourf(xx,yy,z,cmap='viridis')
fig.colorbar(p)

# %%
#contour plot


import matplotlib.pyplot as plt
import numpy as np

# Define dimensions
Nx, Ny, Nz = 100, 300, 500
X, Y, Z = np.meshgrid(np.arange(Nx), np.arange(Ny), -np.arange(Nz))

# Create fake data
data = (((X+100)**2 + (Y-20)**2 + 2*Z)/1000+1)

kw = {
    'vmin': data.min(),
    'vmax': data.max(),
    'levels': np.linspace(data.min(), data.max(), 10),
}


fig = plt.figure(figsize=(5, 4))
ax = fig.add_subplot(111, projection='3d')


_ = ax.contourf(
    X[:, :, 0], Y[:, :, 0], data[:, :, 0],
    zdir='z', offset=0, **kw
)
_ = ax.contourf(
    X[0, :, :], data[0, :, :], Z[0, :, :],
    zdir='y', offset=0, **kw
)
C = ax.contourf(
    data[:, -1, :], Y[:, -1, :], Z[:, -1, :],
    zdir='x', offset=X.max(), **kw
)

xmin, xmax = X.min(), X.max()
ymin, ymax = Y.min(), Y.max()
zmin, zmax = Z.min(), Z.max()
ax.set(xlim=[xmin, xmax], ylim=[ymin, ymax], zlim=[zmin, zmax])

# Plot edges
edges_kw = dict(color='0.4', linewidth=1, zorder=1e3)
ax.plot([xmax, xmax], [ymin, ymax], 0, **edges_kw)
ax.plot([xmin, xmax], [ymin, ymin], 0, **edges_kw)
ax.plot([xmax, xmax], [ymin, ymin], [zmin, zmax], **edges_kw)

# Set labels and zticks
ax.set(
    xlabel='X [km]',
    ylabel='Y [km]',
    zlabel='Z [m]',
    zticks=[0, -150, -300, -450],
)

# Set zoom and angle view
ax.view_init(40, -30, 0)
ax.set_box_aspect(None, zoom=0.9)

# Colorbar
fig.colorbar(C, ax=ax, fraction=0.02, pad=0.1, label='Name [units]')

# Show Figure
plt.show()

# %%
#multiple separate plots together on tips data >> subplots = True
tips.pivot_table(index=['day','time'],columns=['sex','smoker'],values='total_bill',aggfunc='mean').plot(kind='pie',subplots=True,figsize=(20,10))
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_9188\1540720678.py:2: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   tips.pivot_table(index=['day','time'],columns=['sex','smoker'],values='total_bill',aggfunc='mean').plot(kind='pie',subplots=True,figsize=(20,10))
# array([<Axes: ylabel='(Male, Yes)'>, <Axes: ylabel='(Male, No)'>,
#        <Axes: ylabel='(Female, Yes)'>, <Axes: ylabel='(Female, No)'>],
#       dtype=object)

# %%
#changing styles
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('dark_background')

# %%
x = [1, 2, 3, 4]
y = [70, 30, 40, 60]
plt.bar(x, y)
plt.show()

# %%
#To save any figure/plot
x = [1, 2, 3, 4]
y = [70, 30, 40, 60]
plt.bar(x, y)
# plt.show() #dont keep plt.show here otherwise it will not save file
plt.savefig("image.png")
