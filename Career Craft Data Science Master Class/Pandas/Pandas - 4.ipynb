# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#sort a dataframe based on a column
df.sort_values(by = "Fare")
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 271          272         1       3        Tornquist, Mr. William Henry
# 597          598         0       3                 Johnson, Mr. Alfred
# 302          303         0       3     Johnson, Mr. William Cahoone Jr
# 633          634         0       1       Parr, Mr. William Henry Marsh
# 277          278         0       2         Parkes, Mr. Francis "Frank"
# ..           ...       ...     ...                                 ...
# 438          439         0       1                   Fortune, Mr. Mark
# 341          342         1       1      Fortune, Miss. Alice Elizabeth
# 737          738         1       1              Lesurer, Mr. Gustave J
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
df.sort_values(by = "Fare", ascending = False)
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 27            28         0       1      Fortune, Mr. Charles Alexander
# ..           ...       ...     ...                                 ...
# 633          634         0       1       Parr, Mr. William Henry Marsh
# 413          414         0       2      Cunningham, Mr. Alfred Fleming
# 822          823         0       1     Reuchlin, Jonkheer. John George
# 732          733         0       2                Knight, Mr. Robert J
# 674          675         0       2          Watson, Mr. Ennis Hastings
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
#how to sort a df based of two features

df.sort_values(by = ["Fare","Age"], ascending = False)
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
# 438          439         0       1                   Fortune, Mr. Mark
# 341          342         1       1      Fortune, Miss. Alice Elizabeth
# ..           ...       ...     ...                                 ...
# 481          482         0       2    Frost, Mr. Anthony Wood "Archie"
# 633          634         0       1       Parr, Mr. William Henry Marsh
# 674          675         0       2          Watson, Mr. Ennis Hastings
# 732          733         0       2                Knight, Mr. Robert J
# 815          816         0       1                    Fry, Mr. Richard
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
df.sort_values(by = "Name")
#if there is special character, it will come fast
#if the string is there and number is there>> number
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 845          846         0       3                    Abbing, Mr. Anthony
# 746          747         0       3            Abbott, Mr. Rossmore Edward
# 279          280         1       3       Abbott, Mrs. Stanton (Rosa Hunt)
# 308          309         0       2                    Abelson, Mr. Samuel
# 874          875         1       2  Abelson, Mrs. Samuel (Hannah Wizosky)
# ..           ...       ...     ...                                    ...
# 286          287         1       3                de Mulder, Mr. Theodore
# 282          283         0       3              de Pelsmaeker, Mr. Alfons
# 361          362         0       2              del Carlo, Mr. Sebastiano
# 153          154         0       3        van Billiard, Mr. Austin Blyler
# 868          869         0       3            van Melkebeke, Mr. Philemon
#
#         Sex   Age  SibSp  Parch         Ticket     Fare Cabin Embarked
# ...

# %%
#Q What is the average fare paid the people who didnt survived?
df[df.Survived == 0]["Fare"].mean()
# Out:
# 22.117886885245902

# %%
#what if I want the average of all the other columns for the people who survived? >> will do you it one by one >> no
#groupby

#groupby explanation after examples

df.groupby('Survived').mean(numeric_only=True)
# Out:
#           PassengerId    Pclass        Age     SibSp     Parch       Fare
# Survived
# 0          447.016393  2.531876  30.626179  0.553734  0.329690  22.117887
# 1          444.368421  1.950292  28.343690  0.473684  0.464912  48.395408

# %% [markdown]
# ![image.png](attachment:935d84b8-00f5-4945-9374-132f5b37efb6.png)

# %%
#use case 1 >> sales of stores
#Q.Total sales for each store
data = {
    'Store': ['A', 'B', 'A', 'B', 'A', 'C', 'C'],
    'Sales': [200, 150, 300, 100, 250, 400, 350]
}
df = pd.DataFrame(data)
df
# Out:
#   Store  Sales
# 0     A    200
# 1     B    150
# 2     A    300
# 3     B    100
# 4     A    250
# 5     C    400
# 6     C    350

# %%
df.groupby('Store')['Sales'].sum()
# Out:
# Store
# A    750
# B    250
# C    750
# Name: Sales, dtype: int64

# %%
#use case 2
data = {
    'Department': ['HR', 'Tech', 'HR', 'Tech', 'Sales', 'Sales'],
    'Employee': ['Alice', 'Bob', 'Charlie', 'David', 'Eva', 'Frank'],
    'Salary': [50000, 70000, 52000, 75000, 40000, 45000]
}
df = pd.DataFrame(data)

#with respect each department you want average salary
df.groupby('Department')['Salary'].mean()
# Out:
# Department
# HR       51000.0
# Sales    42500.0
# Tech     72500.0
# Name: Salary, dtype: float64

# %%
data = {
    'Class': ['10A', '10A', '10B', '10B', '10C', '10C'],
    'Subject': ['Math', 'English', 'Math', 'English', 'Math', 'English'],
    'Score': [85, 90, 78, 82, 92, 88]
}
df = pd.DataFrame(data)

#with respect to each class calculate average score
df.groupby('Class')['Score'].mean()
# Out:
# Class
# 10A    87.5
# 10B    80.0
# 10C    90.0
# Name: Score, dtype: float64

# %%
#with respect to each class calculate average score in each subject
df.groupby(['Class', 'Subject'])['Score'].mean()
# Out:
# Class  Subject
# 10A    English    90.0
#        Math       85.0
# 10B    English    82.0
#        Math       78.0
# 10C    English    88.0
#        Math       92.0
# Name: Score, dtype: float64

# %%
data = {
    'Customer': ['John', 'Mary', 'Mike', 'Sue', 'Tom'],
    'Age': [25, 40, 25, 30, 40],
    'Purchase_Amount': [200, 300, 150, 100, 250]
}
df = pd.DataFrame(data)
df
#based on different age groups, calculated average purchase amount
# Out:
#   Customer  Age  Purchase_Amount
# 0     John   25              200
# 1     Mary   40              300
# 2     Mike   25              150
# 3      Sue   30              100
# 4      Tom   40              250

# %%
bins = [20, 30, 40, 50]
labels = ['20-30', '30-40', '40-50']

df['Age_group'] = pd.cut(df['Age'], bins = bins, labels=labels, right=False)

# %%
df
# Out:
#   Customer  Age  Purchase_Amount Age_group
# 0     John   25              200     20-30
# 1     Mary   40              300     40-50
# 2     Mike   25              150     20-30
# 3      Sue   30              100     30-40
# 4      Tom   40              250     40-50

# %%
df.groupby('Age_group')['Purchase_Amount'].sum()
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_17976\1952456479.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('Age_group')['Purchase_Amount'].sum()
# Age_group
# 20-30    350
# 30-40    100
# 40-50    550
# Name: Purchase_Amount, dtype: int64

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.groupby(['Survived'])['Fare'].agg([min, 'max', 'mean', 'median', 'count', np.std, 'var'])
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_17976\3371744339.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.groupby(['Survived'])['Fare'].agg([min, 'max', 'mean', 'median', 'count', np.std, 'var'])
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_17976\3371744339.py:1: FutureWarning: The provided callable <function std at 0x0000025534FACFE0> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   df.groupby(['Survived'])['Fare'].agg([min, 'max', 'mean', 'median', 'count', np.std, 'var'])
#           min       max       mean  median  count        std          var
# Survived
# 0         0.0  263.0000  22.117887    10.5    549  31.388207   985.219509
# ...

# %%
#explanation of groupby

df.groupby('Sex')

#it creates groupby object>> This groupby object contains all the segregated groups

# %%
g = df.groupby('Sex')
g

# %%
g = df.groupby('Sex')
g.groups

#these are indexes
# Out:
# {'female': [1, 2, 3, 8, 9, 10, 11, 14, 15, 18, 19, 22, 24, 25, 28, 31, 32, 38, 39, 40, 41, 43, 44, 47, 49, 52, 53, 56, 58, 61, 66, 68, 71, 79, 82, 84, 85, 88, 98, 100, 106, 109, 111, 113, 114, 119, 123, 128, 132, 133, 136, 140, 141, 142, 147, 151, 156, 161, 166, 167, 172, 177, 180, 184, 186, 190, 192, 194, 195, 198, 199, 205, 208, 211, 215, 216, 218, 229, 230, 233, 235, 237, 240, 241, 246, 247, 251, 254, 255, 256, 257, 258, 259, 264, 268, 269, 272, 274, 275, 276, ...], 'male': [0, 4, 5, 6, 7, 12, 13, 16, 17, 20, 21, 23, 26, 27, 29, 30, 33, 34, 35, 36, 37, 42, 45, 46, 48, 50, 51, 54, 55, 57, 59, 60, 62, 63, 64, 65, 67, 69, 70, 72, 73, 74, 75, 76, 77, 78, 80, 81, 83, 86, 87, 89, 90, 91, 92, 93, 94, 95, 96, 97, 99, 101, 102, 103, 104, 105, 107, 108, 110, 112, 115, 116, 117, 118, 120, 121, 122, 124, 125, 126, 127, 129, 130, 131, 134, 135, 137, 138, 139, 143, 144, 145, 146, 148, 149, 150, 152, 153, 154, 155, ...]}

# %%
g.mean('Age') #aggregation is happening
# Out:
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female   431.028662  0.742038  2.159236  27.915709  0.694268  0.649682
# male     454.147314  0.188908  2.389948  30.726645  0.429809  0.235702
#
#              Fare
# Sex
# female  44.479818
# male    25.523893

# %%
g.max('Age')
# Out:
#         PassengerId  Survived  Pclass   Age  SibSp  Parch      Fare
# Sex
# female          889         1       3  63.0      8      6  512.3292
# male            891         1       3  80.0      8      5  512.3292

# %%
g.max('Fare')
# Out:
#         PassengerId  Survived  Pclass   Age  SibSp  Parch      Fare
# Sex
# female          889         1       3  63.0      8      6  512.3292
# male            891         1       3  80.0      8      5  512.3292

# %%
g.describe()
# Out:
#        PassengerId                                                             \
#              count        mean         std  min     25%    50%     75%    max
# Sex
# female       314.0  431.028662  256.846324  2.0  231.75  414.5  641.25  889.0
# male         577.0  454.147314  257.486139  1.0  222.00  464.0  680.00  891.0
#
#        Survived            ... Parch        Fare                              \
#           count      mean  ...   75%  max  count       mean        std   min
# Sex                        ...
# female    314.0  0.742038  ...   1.0  6.0  314.0  44.479818  57.997698  6.75
# male      577.0  0.188908  ...   0.0  5.0  577.0  25.523893  43.138263  0.00
#
#
#               25%   50%    75%       max
# Sex
# female  12.071875  23.0  55.00  512.3292
# male     7.895800  10.5  26.55  512.3292
#
# [2 rows x 56 columns]

# %%
g.sample(2)  #two random sample of each sex
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 830          831         1       3  Yasbeck, Mrs. Antoni (Selini Alexander)
# 22            23         1       3              McGowan, Miss. Anna "Annie"
# 248          249         1       1            Beckwith, Mr. Richard Leonard
# 844          845         0       3                      Culumovic, Mr. Jeso
#
#         Sex   Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 830  female  15.0      1      0    2659  14.4542   NaN        C
# 22   female  15.0      0      0  330923   8.0292   NaN        Q
# 248    male  37.0      1      1   11751  52.5542   D35        S
# 844    male  17.0      0      0  315090   8.6625   NaN        S

# %%
g.nunique()
# Out:
#         PassengerId  Survived  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# Sex
# female          314         2       3   314   63      7      7     247   156
# male            577         2       3   577   82      7      6     519   193
#
#         Cabin  Embarked
# Sex
# female     75         3
# male       96         3

# %%
g.agg(
    {"Survived":'max',
    "Fare": "mean"}
)
# Out:
#         Survived       Fare
# Sex
# female         1  44.479818
# male           1  25.523893

# %%
#Q1. Find the average age of passenger who survived and those who didnt?
df.groupby('Survived')['Age'].mean()
# Out:
# Survived
# 0    30.626179
# 1    28.343690
# Name: Age, dtype: float64

# %%
#Q1. Find the average age of passenger in each Pclass who survived and those who didnt?
df.groupby(['Survived', 'Pclass'])['Age'].mean()
# Out:
# Survived  Pclass
# 0         1         43.695312
#           2         33.544444
#           3         26.555556
# 1         1         35.368197
#           2         25.901566
#           3         20.646118
# Name: Age, dtype: float64

# %%
#which class has the highest proprtion of survivors? #proportion and rate means you have to aggregate average
df.groupby('Pclass')['Survived'].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Which port (embarked) had the highest survival rate?
df.groupby('Embarked')['Survived'].mean()
# Out:
# Embarked
# C    0.553571
# Q    0.389610
# S    0.336957
# Name: Survived, dtype: float64

# %%
#What is the average fare paid by male and female passengers who survived, grouped by class?


df.groupby(["Sex", 'Survived',"Pclass"])["Fare"].mean()
# Out:
# Sex     Survived  Pclass
# female  0         1         110.604167
#                   2          18.250000
#                   3          19.773093
#         1         1         105.978159
#                   2          22.288989
#                   3          12.464526
# male    0         1          62.894910
#                   2          19.488965
#                   3          12.204469
#         1         1          74.637320
#                   2          21.095100
#                   3          15.579696
# Name: Fare, dtype: float64

# %%
df[df['Survived'] == 1].groupby(['Pclass', 'Sex'])['Fare'].mean()
#this method is more optimised as the dataframe is filtered first and then groupedby
# Out:
# Pclass  Sex
# 1       female    105.978159
#         male       74.637320
# 2       female     22.288989
#         male       21.095100
# 3       female     12.464526
#         male       15.579696
# Name: Fare, dtype: float64

# %%
# Find the number of missing values for each column after grouping by 'sex'.

df.groupby('Sex').apply(lambda x: x.isnull().sum())
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_17976\2542508113.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby('Sex').apply(lambda x: x.isnull().sum())
#         PassengerId  Survived  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  \
# Sex
# female            0         0       0     0    0   53      0      0       0
# male              0         0       0     0    0  124      0      0       0
#
#         Fare  Cabin  Embarked
# Sex
# female     0    217         2
# male       0    470         0

# %%
#internal homework
# Identify the age group (e.g., 0-10, 10-20) with the highest survival rate in each class.
#Compare the number of passengers who survived by sex and whether they were alone or with family (SibSp + Parch).
#For each class, calculate the total fare paid by male and female passengers who survived.

# %%
#groupby on imdb dataset
#link>> https://www.kaggle.com/datasets/harshitshankhdhar/imdb-dataset-of-top-1000-movies-and-tv-shows

movies = pd.read_csv("imdb_top_1000.csv")

# %%
movies
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
g = movies.groupby('Genre')

# %%
g.mean(numeric_only = True)
# Out:
#                               IMDB_Rating  Meta_score    No_of_Votes
# Genre
# Action, Adventure                8.180000   71.800000  925533.400000
# Action, Adventure, Biography     7.900000         NaN   52397.000000
# Action, Adventure, Comedy        7.910000   66.857143  456076.600000
# Action, Adventure, Crime         7.600000         NaN   63882.000000
# Action, Adventure, Drama         8.150000   80.461538  663989.928571
# ...                                   ...         ...            ...
# Mystery, Romance, Thriller       8.300000  100.000000  364368.000000
# Mystery, Sci-Fi, Thriller        7.800000   70.000000  383185.000000
# Mystery, Thriller                7.977778   78.600000  341362.888889
# Thriller                         7.800000   81.000000   27733.000000
# Western                          8.350000   78.250000  322416.250000
#
# [202 rows x 3 columns]

# %%
g.std(numeric_only = True)
# Out:
#                               IMDB_Rating  Meta_score    No_of_Votes
# Genre
# Action, Adventure                0.286356    9.731393  509961.879341
# Action, Adventure, Biography          NaN         NaN            NaN
# Action, Adventure, Comedy        0.191195    6.229729  352696.927553
# Action, Adventure, Crime              NaN         NaN            NaN
# Action, Adventure, Drama         0.475152   11.192374  613518.308911
# ...                                   ...         ...            ...
# Mystery, Romance, Thriller            NaN         NaN            NaN
# Mystery, Sci-Fi, Thriller        0.282843    5.656854  276136.511762
# Mystery, Thriller                0.319287   21.137644  463893.426814
# Thriller                              NaN         NaN            NaN
# Western                          0.420317    9.032349  263489.554280
#
# [202 rows x 3 columns]

# %%
movies.sample(1)
# Out:
#                                            Poster_Link    Series_Title  \
# 240  https://m.media-amazon.com/images/M/MV5BMjRjMT...  Dil Chahta Hai
#
#     Released_Year Certificate  Runtime                   Genre  IMDB_Rating  \
# 240          2001     Unrated  183 min  Comedy, Drama, Romance          8.1
#
#                                               Overview  Meta_score  \
# 240  Three inseparable childhood friends are just o...         NaN
#
#           Director       Star1          Star2           Star3         Star4  \
# 240  Farhan Akhtar  Aamir Khan  Saif Ali Khan  Akshaye Khanna  Preity Zinta
#
#      No_of_Votes     Gross
# 240        66803  3,00,000

# %%
movies.dtypes
# Out:
# Poster_Link       object
# Series_Title      object
# Released_Year     object
# Certificate       object
# Runtime           object
# Genre             object
# IMDB_Rating      float64
# Overview          object
# Meta_score       float64
# Director          object
# Star1             object
# Star2             object
# Star3             object
# Star4             object
# No_of_Votes        int64
# Gross             object
# dtype: object

# %%
#find the top 3 genre with highest  IMDB_Rating?
movies.groupby('Genre')['IMDB_Rating'].sum().head(3)
# Out:
# Genre
# Action, Adventure               40.9
# Action, Adventure, Biography     7.9
# Action, Adventure, Comedy       79.1
# Name: IMDB_Rating, dtype: float64

# %%
#find the director with highest popularity? (based on no of votes)
movies.groupby('Director')['No_of_Votes'].sum().sort_values(ascending=False).head(1)
# Out:
# Director
# Christopher Nolan    11578345
# Name: No_of_Votes, dtype: int64

# %%
#find the highest rated movie of each genre?
movies.groupby('Genre')['IMDB_Rating'].max()
# Out:
# Genre
# Action, Adventure               8.4
# Action, Adventure, Biography    7.9
# Action, Adventure, Comedy       8.2
# Action, Adventure, Crime        7.6
# Action, Adventure, Drama        8.9
#                                ...
# Mystery, Romance, Thriller      8.3
# Mystery, Sci-Fi, Thriller       8.0
# Mystery, Thriller               8.4
# Thriller                        7.8
# Western                         8.8
# Name: IMDB_Rating, Length: 202, dtype: float64

# %%
movies.columns
# Out:
# Index(['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
#        'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
#        'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %%
#find the number of movies done by each actor?
movies.groupby('Star1')['Series_Title'].count().sort_values(ascending=False)
# Out:
# Star1
# Tom Hanks             12
# Robert De Niro        11
# Clint Eastwood        10
# Al Pacino             10
# Leonardo DiCaprio      9
#                       ..
# Glen Hansard           1
# Giuseppe Battiston     1
# Giulietta Masina       1
# Gerardo Taracena       1
# Ömer Faruk Sorak       1
# Name: Series_Title, Length: 660, dtype: int64

# %%
g = movies.groupby('Genre')

# %%
g.nunique()
# Out:
#                               Poster_Link  Series_Title  Released_Year  \
# Genre
# Action, Adventure                       5             5              5
# Action, Adventure, Biography            1             1              1
# Action, Adventure, Comedy              10            10              8
# Action, Adventure, Crime                1             1              1
# Action, Adventure, Drama               14            14             11
# ...                                   ...           ...            ...
# Mystery, Romance, Thriller              1             1              1
# Mystery, Sci-Fi, Thriller               2             2              2
# Mystery, Thriller                       9             9              8
# Thriller                                1             1              1
# Western                                 4             4              4
#
#                               Certificate  Runtime  IMDB_Rating  Overview  \
# Genre
# ...

# %%
len(movies.groupby('Genre'))
# Out:
# 202

# %%
movies.Genre.nunique()
# Out:
# 202

# %%
#find the Action genre group?
g.get_group("Drama")
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 9    https://m.media-amazon.com/images/M/MV5BMmEzNT...
# 17   https://m.media-amazon.com/images/M/MV5BZjA0OW...
# 20   https://m.media-amazon.com/images/M/MV5BOTc2ZT...
# 40   https://m.media-amazon.com/images/M/MV5BZjA0MT...
# ..                                                 ...
# 933  https://m.media-amazon.com/images/M/MV5BMjA0Mj...
# 934  https://m.media-amazon.com/images/M/MV5BMTgxMj...
# 941  https://m.media-amazon.com/images/M/MV5BNmE0Yj...
# 946  https://m.media-amazon.com/images/M/MV5BNDhjMz...
# 981  https://m.media-amazon.com/images/M/MV5BNWQ4MG...
#
#                         Series_Title Released_Year Certificate  Runtime  \
# 0           The Shawshank Redemption          1994           A  142 min
# 9                         Fight Club          1999           A  139 min
# 17   One Flew Over the Cuckoo's Nest          1975           A  133 min
# ...

# %%
movies.Genre
# Out:
# 0                         Drama
# 1                  Crime, Drama
# 2          Action, Crime, Drama
# 3                  Crime, Drama
# 4                  Crime, Drama
#                  ...
# 995      Comedy, Drama, Romance
# 996              Drama, Western
# 997         Drama, Romance, War
# 998                  Drama, War
# 999    Crime, Mystery, Thriller
# Name: Genre, Length: 1000, dtype: object

# %%
#find the number of movies starting with A for each group
#movie name is Series_Title

# %%
g

# %%
def func(group):
    return group.Series_Title.str.startswith("A").sum()

# %%
g.apply(func)
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_17976\2374567978.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   g.apply(func)
# Genre
# Action, Adventure               0
# Action, Adventure, Biography    1
# Action, Adventure, Comedy       0
# Action, Adventure, Crime        0
# Action, Adventure, Drama        2
#                                ..
# Mystery, Romance, Thriller      0
# Mystery, Sci-Fi, Thriller       0
# Mystery, Thriller               0
# Thriller                        0
# Western                         0
# Length: 202, dtype: int64

# %%
movies.columns
# Out:
# Index(['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
#        'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
#        'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %%
#find the ranking of each movie in each genre as per IMDB_Rating
#find the normalized IMDB_Rating group wise (x-xmin()/xmin()-xmax())
#find all the groups with each combination of director and Star1 (director and actor combo)
#find the top 10 movies in terms of metascore and IMDB_Rating

# %%
#null value treatment

# %%
df1 = pd.read_csv("taxonomy.csv")

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.isna().sum()
# Out:
# taxonomy_id     0
# name            0
# parent_id      11
# parent_name    11
# dtype: int64

# %%
df1.shape
# Out:
# (290, 4)

# %%
df1.dropna() #drop the null values from the rows
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
#drop column wise
df1.dropna(axis=1)
# Out:
#     taxonomy_id                          name
# 0           101                     Emergency
# 1        101-01             Disaster Response
# 2        101-02                Emergency Cash
# 3     101-02-01             Help Pay for Food
# 4     101-02-02       Help Pay for Healthcare
# ..          ...                           ...
# 285   111-01-07              Workplace Rights
# 286      111-02                     Mediation
# 287      111-03                        Notary
# 288      111-04                Representation
# 289      111-05  Translation & Interpretation
#
# [290 rows x 2 columns]

# %%
df1[["name"]].dropna(axis=0) #for one column
# Out:
#                              name
# 0                       Emergency
# 1               Disaster Response
# 2                  Emergency Cash
# 3               Help Pay for Food
# 4         Help Pay for Healthcare
# ..                            ...
# 285              Workplace Rights
# 286                     Mediation
# 287                        Notary
# 288                Representation
# 289  Translation & Interpretation
#
# [290 rows x 1 columns]

# %%
#imputation of missing value
#numeric data >> mean and median >> if outlier treatment is done,then replace missing value with mean otherwise median
#categorical data>> mode
#imputing missing value with some constat >> 0
#bfill and fill >> time series data

# %%
df1.fillna("somevalue")
# Out:
#     taxonomy_id                          name  parent_id           parent_name
# 0           101                     Emergency  somevalue             somevalue
# 1        101-01             Disaster Response        101             Emergency
# 2        101-02                Emergency Cash        101             Emergency
# 3     101-02-01             Help Pay for Food     101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare     101-02        Emergency Cash
# ..          ...                           ...        ...                   ...
# 285   111-01-07              Workplace Rights     111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation        111                 Legal
# 287      111-03                        Notary        111                 Legal
# 288      111-04                Representation        111                 Legal
# 289      111-05  Translation & Interpretation        111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.fillna(0)
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency         0                     0
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
data1 = {
    'A': [1, 2, None, 4, 5, None, 7, 8, 9, 10],
    'B': [None, 11, 12, 13, None, 15, 16, None, 18, 19]
}

df2 = pd.DataFrame(data1)
df2
# Out:
#       A     B
# 0   1.0   NaN
# 1   2.0  11.0
# 2   NaN  12.0
# 3   4.0  13.0
# 4   5.0   NaN
# 5   NaN  15.0
# 6   7.0  16.0
# 7   8.0   NaN
# 8   9.0  18.0
# 9  10.0  19.0

# %%
df2.A.fillna(df2["A"].mean())
# Out:
# 0     1.00
# 1     2.00
# 2     5.75
# 3     4.00
# 4     5.00
# 5     5.75
# 6     7.00
# 7     8.00
# 8     9.00
# 9    10.00
# Name: A, dtype: float64

# %%
df2.A.fillna(df2["A"].median())
# Out:
# 0     1.0
# 1     2.0
# 2     6.0
# 3     4.0
# 4     5.0
# 5     6.0
# 6     7.0
# 7     8.0
# 8     9.0
# 9    10.0
# Name: A, dtype: float64

# %%
df2.A.fillna(0)
# Out:
# 0     1.0
# 1     2.0
# 2     0.0
# 3     4.0
# 4     5.0
# 5     0.0
# 6     7.0
# 7     8.0
# 8     9.0
# 9    10.0
# Name: A, dtype: float64

# %%
df2.fillna("something")
# Out:
#            A          B
# 0        1.0  something
# 1        2.0       11.0
# 2  something       12.0
# 3        4.0       13.0
# 4        5.0  something
# 5  something       15.0
# 6        7.0       16.0
# 7        8.0  something
# 8        9.0       18.0
# 9       10.0       19.0

# %%
df2.fillna(method = 'ffill') #forward fill >> start seeing from the bottom of dataframe and fill with next value observed
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_17976\1901163218.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df2.fillna(method = 'ffill') #forward fill >> start seeing from the bottom of dataframe and fill with next value observed
#       A     B
# 0   1.0   NaN
# 1   2.0  11.0
# 2   2.0  12.0
# 3   4.0  13.0
# 4   5.0  13.0
# 5   5.0  15.0
# 6   7.0  16.0
# 7   8.0  16.0
# 8   9.0  18.0
# 9  10.0  19.0

# %%
df2.fillna(method = 'bfill') #backwardfill >> see from the and fill with the next observed value
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_17976\4113798047.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df2.fillna(method = 'bfill') #backwardfill >> see from the and fill with the next observed value
#       A     B
# 0   1.0  11.0
# 1   2.0  11.0
# 2   4.0  12.0
# 3   4.0  13.0
# 4   5.0  15.0
# 5   7.0  15.0
# 6   7.0  16.0
# 7   8.0  18.0
# 8   9.0  18.0
# 9  10.0  19.0

# %%
df2.mean()
# Out:
# A     5.750000
# B    14.857143
# dtype: float64

# %%
df2.std()
# Out:
# A    3.284161
# B    3.023716
# dtype: float64

# %%
df2.max()
# Out:
# A    10.0
# B    19.0
# dtype: float64

# %%
df2.var()
# Out:
# A    10.785714
# B     9.142857
# dtype: float64

# %%
df2.median()
# Out:
# A     6.0
# B    15.0
# dtype: float64

# %%
#checking duplicate values
df2.duplicated().sum()
# Out:
# 0

# %%
df2.drop_duplicates()
# Out:
#       A     B
# 0   1.0   NaN
# 1   2.0  11.0
# 2   NaN  12.0
# 3   4.0  13.0
# 4   5.0   NaN
# 5   NaN  15.0
# 6   7.0  16.0
# 7   8.0   NaN
# 8   9.0  18.0
# 9  10.0  19.0
