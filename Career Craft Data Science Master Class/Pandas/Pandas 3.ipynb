# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
"monjolika" + " baby"
# Out:
# 'monjolika baby'

# %%
df1 = df[["Name", "Sex", "Age"]][0:5]

# %%
df2 = df[["Name", "Sex", "Age"]][5:10]

# %%
df1
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0

# %%
df2
# Out:
#                                                 Name     Sex   Age
# 5                                   Moran, Mr. James    male   NaN
# 6                            McCarthy, Mr. Timothy J    male  54.0
# 7                     Palsson, Master. Gosta Leonard    male   2.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
pd.concat([df1, df2], axis=0) #conactenate/combine pandas object along a particular axis
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 5                                   Moran, Mr. James    male   NaN
# 6                            McCarthy, Mr. Timothy J    male  54.0
# 7                     Palsson, Master. Gosta Leonard    male   2.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
pd.concat([df1, df2], axis=1) #due to indexes you will get null values
# Out:
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 5                                                NaN     NaN   NaN
# 6                                                NaN     NaN   NaN
# 7                                                NaN     NaN   NaN
# 8                                                NaN     NaN   NaN
# 9                                                NaN     NaN   NaN
#
#                                                 Name     Sex   Age
# 0                                                NaN     NaN   NaN
# 1                                                NaN     NaN   NaN
# ...

# %%
df2.reset_index(drop=True, inplace=True)

# %%
df2
# Out:
#                                                 Name     Sex   Age
# 0                                   Moran, Mr. James    male   NaN
# 1                            McCarthy, Mr. Timothy J    male  54.0
# 2                     Palsson, Master. Gosta Leonard    male   2.0
# 3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 4                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
df1
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0

# %%
pd.concat([df1, df2], axis=1)
# Out:
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
#
#                                                 Name     Sex   Age
# 0                                   Moran, Mr. James    male   NaN
# 1                            McCarthy, Mr. Timothy J    male  54.0
# 2                     Palsson, Master. Gosta Leonard    male   2.0
# 3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 4                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
a = pd.concat([df1, df2], axis=1)
a
# Out:
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
#
#                                                 Name     Sex   Age
# 0                                   Moran, Mr. James    male   NaN
# 1                            McCarthy, Mr. Timothy J    male  54.0
# 2                     Palsson, Master. Gosta Leonard    male   2.0
# 3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 4                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
a["Name"]
#duplicate names of columns creates ambiguity
# Out:
#                                                 Name  \
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                             Heikkinen, Miss. Laina
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                           Allen, Mr. William Henry
#
#                                                 Name
# 0                                   Moran, Mr. James
# 1                            McCarthy, Mr. Timothy J
# 2                     Palsson, Master. Gosta Leonard
# 3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 4                Nasser, Mrs. Nicholas (Adele Achem)

# %%
#industry use case of concate ,example:1

#there is an ecommerce store, we have sales data of two months, jan and february

# %%
data_jan = {
    "Store": ["Store A", "Store B"],
    "Sales": [300, 1500]
}
df_jan = pd.DataFrame(data_jan)
df_jan
# Out:
#      Store  Sales
# 0  Store A    300
# 1  Store B   1500

# %%
data_Feb = {
    "Store": ["Store A", "Store B"],
    "Sales": [400, 1100]
}
df_Feb = pd.DataFrame(data_Feb)
df_Feb
# Out:
#      Store  Sales
# 0  Store A    400
# 1  Store B   1100

# %%
#what is the total sale in the whole the year

# %%
pd.concat([df_jan, df_Feb])
# Out:
#      Store  Sales
# 0  Store A    300
# 1  Store B   1500
# 0  Store A    400
# 1  Store B   1100

# %%
pd.concat([df_jan, df_Feb], ignore_index=True)
#by default axis = 0
# Out:
#      Store  Sales
# 0  Store A    300
# 1  Store B   1500
# 2  Store A    400
# 3  Store B   1100

# %%
a = pd.concat([df_jan, df_Feb], ignore_index=True)
a.Sales.sum()
# Out:
# 3300

# %%
#concatenation axis=1 application
#Analogy>> you have gone to watch a movie, you scanned your ticket (data recorded), you got a popkorn (data recorded)
#assuming all this data is recorded in sequential, you can use cancate axis=1 to combine the data

# %%
data_jan = {
    "Store": ["Store A", "Store B"],
    "Sales": [300, 1500]
}
df_jan = pd.DataFrame(data_jan)
df_jan
# Out:
#      Store  Sales
# 0  Store A    300
# 1  Store B   1500

# %%
data_jan = {
    "Value": [1300, 1600],
    "Ocuupied_space": [122, 233]
}
df_jan_d = pd.DataFrame(data_jan)
df_jan_d
# Out:
#    Value  Ocuupied_space
# 0   1300             122
# 1   1600             233

# %%
pd.concat([df_jan, df_jan_d],axis=1)
# Out:
#      Store  Sales  Value  Ocuupied_space
# 0  Store A    300   1300             122
# 1  Store B   1500   1600             233

# %%
#Example 2:

data_dept1 = {
    'EmployeeID': [1, 2],
    'Name': ['Alice', 'Bob'],
    'Salary': [60000, 65000],
    'Department': ['HR', 'HR']
}
df_dept1 = pd.DataFrame(data_dept1)


data_dept2 = {
    'EmployeeID': [3, 4],
    'Name': ['Charlie', 'David'],
    'Salary': [70000, 72000],
    'Department': ['IT', 'IT']
}
df_dept2 = pd.DataFrame(data_dept2)

# %%
df_dept1
# Out:
#    EmployeeID   Name  Salary Department
# 0           1  Alice   60000         HR
# 1           2    Bob   65000         HR

# %%
df_dept2
# Out:
#    EmployeeID     Name  Salary Department
# 0           3  Charlie   70000         IT
# 1           4    David   72000         IT

# %%
#both the dataframe have same column name, we just need to concatenate

pd.concat([df_dept1, df_dept2], ignore_index=True)
# Out:
#    EmployeeID     Name  Salary Department
# 0           1    Alice   60000         HR
# 1           2      Bob   65000         HR
# 2           3  Charlie   70000         IT
# 3           4    David   72000         IT

# %%
#what if there is some null value>> no any problem

#Example 2:

data_dept1 = {
    'EmployeeID': [1, 2],
    'Name': ['Alice', 'Bob'],
    'Salary': [60000, np.NaN],
    'Department': ['HR', 'HR']
}
df_dept1 = pd.DataFrame(data_dept1)


data_dept2 = {
    'EmployeeID': [3, 4],
    'Name': ['Charlie', 'David'],
    'Salary': [70000, 72000],
    'Department': ['IT', 'IT']
}
df_dept2 = pd.DataFrame(data_dept2)

# %%
pd.concat([df_dept1, df_dept2], ignore_index=True)
# Out:
#    EmployeeID     Name   Salary Department
# 0           1    Alice  60000.0         HR
# 1           2      Bob      NaN         HR
# 2           3  Charlie  70000.0         IT
# 3           4    David  72000.0         IT

# %%
#example 2

data_week1 = {
    'Customer': ['John', 'Emily'],
    'Rating': [4, 5],
    'Feedback': ['Good service', 'Excellent experience']
}
df_week1 = pd.DataFrame(data_week1)

data_week2 = {
    'Customer': ['Michael', 'Sarah'],
    'Rating': [3, 4],
    'Feedback': ['Average service', 'Very helpful staff']
}
df_week2 = pd.DataFrame(data_week2)

# %%
df_week1
# Out:
#   Customer  Rating              Feedback
# 0     John       4          Good service
# 1    Emily       5  Excellent experience

# %%
df_week2
# Out:
#   Customer  Rating            Feedback
# 0  Michael       3     Average service
# 1    Sarah       4  Very helpful staff

# %%
pd.concat([df_week1, df_week2], ignore_index=True)
# Out:
#   Customer  Rating              Feedback
# 0     John       4          Good service
# 1    Emily       5  Excellent experience
# 2  Michael       3       Average service
# 3    Sarah       4    Very helpful staff

# %%
#key take away >>  combining data
#example>> sales of multiple month, combining employee data from multiple departements, customer feedback combining for multiple weeks

# %%
#merge
#merge needs a common column to be merged while concatenation doesnt need

# %%
data = {'StoreA':[100, 200, 312, 410, 321],
       'StoreB': [121, 130, 142, 170, 182],
       'StoreC':[111, 121, 123, 124, 191]}
df1 = pd.DataFrame(data)

# %%
data = {'StoreA':[100, 200, 311, 410, 322],
       'StoreD': [12, 130, 142, 170, 322],
       'StoreE':[111, 124, 123, 124, 124]}
df2 = pd.DataFrame(data)

# %%
df1
# Out:
#    StoreA  StoreB  StoreC
# 0     100     121     111
# 1     200     130     121
# 2     312     142     123
# 3     410     170     124
# 4     321     182     191

# %%
df2
# Out:
#    StoreA  StoreD  StoreE
# 0     100      12     111
# 1     200     130     124
# 2     311     142     123
# 3     410     170     124
# 4     322     322     124

# %%
pd.merge(df1, df2, how = 'inner')
#common column, matching values are used to merge
# Out:
#    StoreA  StoreB  StoreC  StoreD  StoreE
# 0     100     121     111      12     111
# 1     200     130     121     130     124
# 2     410     170     124     170     124

# %%
pd.merge(df1, df2, how = 'left')
# Out:
#    StoreA  StoreB  StoreC  StoreD  StoreE
# 0     100     121     111    12.0   111.0
# 1     200     130     121   130.0   124.0
# 2     312     142     123     NaN     NaN
# 3     410     170     124   170.0   124.0
# 4     321     182     191     NaN     NaN

# %%
pd.merge(df1, df2, how = 'right')
# Out:
#    StoreA  StoreB  StoreC  StoreD  StoreE
# 0     100   121.0   111.0      12     111
# 1     200   130.0   121.0     130     124
# 2     311     NaN     NaN     142     123
# 3     410   170.0   124.0     170     124
# 4     322     NaN     NaN     322     124

# %%
pd.merge(df1, df2, how = 'outer')
#it is call full merge, and it considers the common column all the values from both the datframe
#all the keys from both the dataframe
# Out:
#    StoreA  StoreB  StoreC  StoreD  StoreE
# 0     100   121.0   111.0    12.0   111.0
# 1     200   130.0   121.0   130.0   124.0
# 2     311     NaN     NaN   142.0   123.0
# 3     312   142.0   123.0     NaN     NaN
# 4     321   182.0   191.0     NaN     NaN
# 5     322     NaN     NaN   322.0   124.0
# 6     410   170.0   124.0   170.0   124.0

# %%
df1
# Out:
#    StoreA  StoreB  StoreC
# 0     100     121     111
# 1     200     130     121
# 2     312     142     123
# 3     410     170     124
# 4     321     182     191

# %%
df2
# Out:
#    StoreA  StoreD  StoreE
# 0     100      12     111
# 1     200     130     124
# 2     311     142     123
# 3     410     170     124
# 4     322     322     124

# %%
pd.merge(df1, df2, how = 'cross')
#cartesian product of the dataframe
#use case of this:
#Analogy, there are four persons in one dataframe and in another dataframe there are places to visit
#if all the person wants to visit all the place, use cross merge
#since we had the same name StoreA in both the column, the merge has changed its name to differentiate
# Out:
#     StoreA_x  StoreB  StoreC  StoreA_y  StoreD  StoreE
# 0        100     121     111       100      12     111
# 1        100     121     111       200     130     124
# 2        100     121     111       311     142     123
# 3        100     121     111       410     170     124
# 4        100     121     111       322     322     124
# 5        200     130     121       100      12     111
# 6        200     130     121       200     130     124
# 7        200     130     121       311     142     123
# 8        200     130     121       410     170     124
# 9        200     130     121       322     322     124
# 10       312     142     123       100      12     111
# 11       312     142     123       200     130     124
# 12       312     142     123       311     142     123
# 13       312     142     123       410     170     124
# 14       312     142     123       322     322     124
# 15       410     170     124       100      12     111
# ...

# %%
#do we need to have common column in both thge dataframe to have cross merge >> No
#store A in 2nd datframe has been changed to StoreF
data = {'StoreA':[100, 200, 312, 410, 321],
       'StoreB': [121, 130, 142, 170, 182],
       'StoreC':[111, 121, 123, 124, 191]}
df1 = pd.DataFrame(data)

data = {'StoreF':[100, 200, 311, 410, 322],
       'StoreD': [12, 130, 142, 170, 322],
       'StoreE':[111, 124, 123, 124, 124]}
df2 = pd.DataFrame(data)


pd.merge(df1, df2, how = 'cross')
# Out:
#     StoreA  StoreB  StoreC  StoreF  StoreD  StoreE
# 0      100     121     111     100      12     111
# 1      100     121     111     200     130     124
# 2      100     121     111     311     142     123
# 3      100     121     111     410     170     124
# 4      100     121     111     322     322     124
# 5      200     130     121     100      12     111
# 6      200     130     121     200     130     124
# 7      200     130     121     311     142     123
# 8      200     130     121     410     170     124
# 9      200     130     121     322     322     124
# 10     312     142     123     100      12     111
# 11     312     142     123     200     130     124
# 12     312     142     123     311     142     123
# 13     312     142     123     410     170     124
# 14     312     142     123     322     322     124
# 15     410     170     124     100      12     111
# 16     410     170     124     200     130     124
# ...

# %%
#what if the common column name is different and we have to do left merge?


data = {'StoreA':[100, 200, 312, 410, 321],
       'StoreB': [121, 130, 142, 170, 182],
       'StoreC':[111, 121, 123, 124, 191]}
df1 = pd.DataFrame(data)

data = {'Store_a':[100, 200, 311, 410, 322],
       'StoreD': [12, 130, 142, 170, 322],
       'StoreE':[111, 124, 123, 124, 124]}
df2 = pd.DataFrame(data)


pd.merge(df1, df2, how = 'left', left_on="StoreA", right_on="Store_a")
#similar thing can be done on other merge if common column name is different
# Out:
#    StoreA  StoreB  StoreC  Store_a  StoreD  StoreE
# 0     100     121     111    100.0    12.0   111.0
# 1     200     130     121    200.0   130.0   124.0
# 2     312     142     123      NaN     NaN     NaN
# 3     410     170     124    410.0   170.0   124.0
# 4     321     182     191      NaN     NaN     NaN

# %%
#Can we achieve right merge using left in the how parameter of merge
pd.merge(df2, df1, how = 'left', right_on="StoreA", left_on="Store_a")
# Out:
#    Store_a  StoreD  StoreE  StoreA  StoreB  StoreC
# 0      100      12     111   100.0   121.0   111.0
# 1      200     130     124   200.0   130.0   121.0
# 2      311     142     123     NaN     NaN     NaN
# 3      410     170     124   410.0   170.0   124.0
# 4      322     322     124     NaN     NaN     NaN

# %%
#what if in the merge you have null values

data = {'StoreA':[100, 200, 312, 410, 321],
       'StoreB': [121, 130, 142, 170, 182],
       'StoreC':[111, 121, 123, 124, 191]}
df1 = pd.DataFrame(data)

data = {'StoreA':[100, np.NaN, 311, 410, 322],
       'StoreD': [12, 130, 142, 170, 322],
       'StoreE':[111, 124, 123, 124, 124]}
df2 = pd.DataFrame(data)

pd.merge(df1, df2, how = 'left')

#In this case null value behaves normally as not a common eleement
# Out:
#    StoreA  StoreB  StoreC  StoreD  StoreE
# 0     100     121     111    12.0   111.0
# 1     200     130     121     NaN     NaN
# 2     312     142     123     NaN     NaN
# 3     410     170     124   170.0   124.0
# 4     321     182     191     NaN     NaN

# %%
data = {'StoreA':[100, np.NaN, 312, 410, 321],
       'StoreB': [121, 130, 142, 170, 182],
       'StoreC':[111, 121, 123, 124, 191]}
df1 = pd.DataFrame(data)

data = {'StoreA':[100, 200, 311, 410, 322],
       'StoreD': [12, 130, 142, 170, 322],
       'StoreE':[111, 124, 123, 124, 124]}
df2 = pd.DataFrame(data)

pd.merge(df1, df2, how = 'left')
#In this case null value behaves normally as not a common eleement
# Out:
#    StoreA  StoreB  StoreC  StoreD  StoreE
# 0   100.0     121     111    12.0   111.0
# 1     NaN     130     121     NaN     NaN
# 2   312.0     142     123     NaN     NaN
# 3   410.0     170     124   170.0   124.0
# 4   321.0     182     191     NaN     NaN

# %%
data = {'StoreA':[100, np.NaN, 312, 410, 321],
       'StoreB': [121, 130, 142, 170, 182],
       'StoreC':[111, 121, 123, 124, 191]}
df1 = pd.DataFrame(data)

data = {'StoreA':[100, np.NaN, 311, 410, 322],
       'StoreD': [12, 130, 142, 170, 322],
       'StoreE':[111, 124, 123, 124, 124]}
df2 = pd.DataFrame(data)

pd.merge(df1, df2, how = 'left')


#observation
#Two NaN are not equal
# Out:
#    StoreA  StoreB  StoreC  StoreD  StoreE
# 0   100.0     121     111    12.0   111.0
# 1     NaN     130     121   130.0   124.0
# 2   312.0     142     123     NaN     NaN
# 3   410.0     170     124   170.0   124.0
# 4   321.0     182     191     NaN     NaN

# %%
data = {'StoreA':[100, None, 312, 410, 321],
       'StoreB': [121, 130, 142, 170, 182],
       'StoreC':[111, 121, 123, 124, 191]}
df1 = pd.DataFrame(data)

data = {'StoreA':[100, None, 311, 410, 322],
       'StoreD': [12, 130, 142, 170, 322],
       'StoreE':[111, 124, 123, 124, 124]}
df2 = pd.DataFrame(data)

pd.merge(df1, df2, how = 'left')
# Out:
#    StoreA  StoreB  StoreC  StoreD  StoreE
# 0   100.0     121     111    12.0   111.0
# 1     NaN     130     121   130.0   124.0
# 2   312.0     142     123     NaN     NaN
# 3   410.0     170     124   170.0   124.0
# 4   321.0     182     191     NaN     NaN

# %%
#values are repeating >> left merge >> doent make a difference
data = {'StoreA':[100, np.NaN, 100, 410, 321],
       'StoreB': [121, 130, 142, 170, 182],
       'StoreC':[111, 121, 123, 124, 191]}
df1 = pd.DataFrame(data)

data = {'StoreA':[100, np.NaN, 311, 410, 322],
       'StoreD': [12, 130, 142, 170, 322],
       'StoreE':[111, 124, 123, 124, 124]}
df2 = pd.DataFrame(data)

pd.merge(df1, df2, how = 'left')
# Out:
#    StoreA  StoreB  StoreC  StoreD  StoreE
# 0   100.0     121     111    12.0   111.0
# 1     NaN     130     121   130.0   124.0
# 2   100.0     142     123    12.0   111.0
# 3   410.0     170     124   170.0   124.0
# 4   321.0     182     191     NaN     NaN

# %%
#null with inner merge
data = {'StoreA':[100, np.NaN, 100, 410, 321],
       'StoreB': [121, 130, 142, 170, 182],
       'StoreC':[111, 121, 123, 124, 191]}
df1 = pd.DataFrame(data)

data = {'StoreA':[100, np.NaN, 311, 410, 322],
       'StoreD': [12, 130, 142, 170, 322],
       'StoreE':[111, 124, 123, 124, 124]}
df2 = pd.DataFrame(data)

pd.merge(df1, df2, how = 'inner')
# Out:
#    StoreA  StoreB  StoreC  StoreD  StoreE
# 0   100.0     121     111      12     111
# 1     NaN     130     121     130     124
# 2   100.0     142     123      12     111
# 3   410.0     170     124     170     124

# %%
#values are repeating >> inner

data = {'StoreA':[100, np.NaN, 100, 410, 321],
       'StoreB': [121, 130, 142, 170, 182],
       'StoreC':[111, 121, 123, 124, 191]}
df1 = pd.DataFrame(data)

data = {'StoreA':[100, np.NaN, 311, 410, 322],
       'StoreD': [12, 130, 142, 170, 322],
       'StoreE':[111, 124, 123, 124, 124]}
df2 = pd.DataFrame(data)

pd.merge(df1, df2, how = 'inner')
#if the value of df1 is repeated then it will repeat the corresponding df2 values
# Out:
#    StoreA  StoreB  StoreC  StoreD  StoreE
# 0   100.0     121     111      12     111
# 1     NaN     130     121     130     124
# 2   100.0     142     123      12     111
# 3   410.0     170     124     170     124

# %%
#if in both the datframe multiple common elements are repeated, it will do all combination

data = {'StoreA':[100, np.NaN, 100, 410, 321],
       'StoreB': [121, 130, 142, 170, 182],
       'StoreC':[111, 121, 123, 124, 191]}
df1 = pd.DataFrame(data)

data = {'StoreA':[100, np.NaN, 100, 410, 322],
       'StoreD': [12, 130, 142, 170, 322],
       'StoreE':[111, 124, 123, 124, 124]}
df2 = pd.DataFrame(data)

pd.merge(df1, df2, how = 'inner')
# Out:
#    StoreA  StoreB  StoreC  StoreD  StoreE
# 0   100.0     121     111      12     111
# 1   100.0     121     111     142     123
# 2     NaN     130     121     130     124
# 3   100.0     142     123      12     111
# 4   100.0     142     123     142     123
# 5   410.0     170     124     170     124

# %%
df1
# Out:
#    StoreA  StoreB  StoreC
# 0   100.0     121     111
# 1     NaN     130     121
# 2   100.0     142     123
# 3   410.0     170     124
# 4   321.0     182     191

# %%
df2
# Out:
#    StoreA  StoreD  StoreE
# 0   100.0      12     111
# 1     NaN     130     124
# 2   100.0     142     123
# 3   410.0     170     124
# 4   322.0     322     124

# %%
#problem when a lot of values of common column are repeated during inner merge
#The number of rows will increase, it might explode leading to wrong claculation and memory error
#if not an option you can merge with duplicate values as well because logically its correct, it is just that your no of rows will increase
#solution>> drop the duplicate values of the common column upon connecting to business team and then do inner merge
#or create a primary key by concatenating two columns

# %%
#in industry you will be using left merge and inner merge

# %%
#join

#everything remains the same, only the difference is that the join happens on index

# %%
df1 = pd.DataFrame({'key1':[1,2,4,5,6],
                      'key2':[4,5,6,7,8],
                      'key3':[3,4,5,6,6]},
                    index = ['a', 'b', 'c', 'd', 'e']
)

df2 =  pd.DataFrame({'key6':[1,2,45,6,67],
                      'key4':[56,5,6,7,8],
                      'key5':[3,56,5,6,6]
},
index = ['a', 'b', 'h', 'i', 'j']
)

# %%
df1
# Out:
#    key1  key2  key3
# a     1     4     3
# b     2     5     4
# c     4     6     5
# d     5     7     6
# e     6     8     6

# %%
df2
# Out:
#    key6  key4  key5
# a     1    56     3
# b     2     5    56
# h    45     6     5
# i     6     7     6
# j    67     8     6

# %%
df1.join(df2, how='inner')
# Out:
#    key1  key2  key3  key6  key4  key5
# a     1     4     3     1    56     3
# b     2     5     4     2     5    56

# %%
df1.join(df2, how='left')
# Out:
#    key1  key2  key3  key6  key4  key5
# a     1     4     3   1.0  56.0   3.0
# b     2     5     4   2.0   5.0  56.0
# c     4     6     5   NaN   NaN   NaN
# d     5     7     6   NaN   NaN   NaN
# e     6     8     6   NaN   NaN   NaN

# %%
df1.join(df2, how='right')
# Out:
#    key1  key2  key3  key6  key4  key5
# a   1.0   4.0   3.0     1    56     3
# b   2.0   5.0   4.0     2     5    56
# h   NaN   NaN   NaN    45     6     5
# i   NaN   NaN   NaN     6     7     6
# j   NaN   NaN   NaN    67     8     6

# %%
df1.join(df2, how='outer')
# Out:
#    key1  key2  key3  key6  key4  key5
# a   1.0   4.0   3.0   1.0  56.0   3.0
# b   2.0   5.0   4.0   2.0   5.0  56.0
# c   4.0   6.0   5.0   NaN   NaN   NaN
# d   5.0   7.0   6.0   NaN   NaN   NaN
# e   6.0   8.0   6.0   NaN   NaN   NaN
# h   NaN   NaN   NaN  45.0   6.0   5.0
# i   NaN   NaN   NaN   6.0   7.0   6.0
# j   NaN   NaN   NaN  67.0   8.0   6.0

# %%
df1.join(df2, how='cross')
# Out:
#     key1  key2  key3  key6  key4  key5
# 0      1     4     3     1    56     3
# 1      1     4     3     2     5    56
# 2      1     4     3    45     6     5
# 3      1     4     3     6     7     6
# 4      1     4     3    67     8     6
# 5      2     5     4     1    56     3
# 6      2     5     4     2     5    56
# 7      2     5     4    45     6     5
# 8      2     5     4     6     7     6
# 9      2     5     4    67     8     6
# 10     4     6     5     1    56     3
# 11     4     6     5     2     5    56
# 12     4     6     5    45     6     5
# 13     4     6     5     6     7     6
# 14     4     6     5    67     8     6
# 15     5     7     6     1    56     3
# 16     5     7     6     2     5    56
# 17     5     7     6    45     6     5
# 18     5     7     6     6     7     6
# 19     5     7     6    67     8     6
# 20     6     8     6     1    56     3
# 21     6     8     6     2     5    56
# 22     6     8     6    45     6     5
# ...

# %%
#convert Fare in euro to inr
# df["Fare"] = df["Fare"] * 90

# %%
#another way
df["Fare"].apply(lambda x: x*90)
# Out:
# 0       652.500
# 1      6415.497
# 2       713.250
# 3      4779.000
# 4       724.500
#          ...
# 886    1170.000
# 887    2700.000
# 888    2110.500
# 889    2700.000
# 890     697.500
# Name: Fare, Length: 891, dtype: float64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
len("Monjolika")
# Out:
# 9

# %%
df["Name_len"] = df["Name"].apply(len)

# %%
df["Name_len"]
# Out:
# 0      23
# 1      51
# 2      22
# 3      44
# 4      24
#        ..
# 886    21
# 887    28
# 888    40
# 889    21
# 890    19
# Name: Name_len, Length: 891, dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#bucket the age column
#if age< 25, >> young
#if age greater than 25 and less than 45 >> matured
#if age > 45>> old

# %%
def age_bucket(age):
    if age < 25:
        return 'young'
    elif 25<=age<=45:
        return 'matured'
    else:
        return 'old'

# %%
df["Age_bucket"] = df["Age"].apply(age_bucket)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#another method
bins = [0, 25, 45, float('inf')] #edges of the bins
labels = ['young', 'matured', 'old']
pd.cut(df["Age"], bins = bins, labels=labels, right=False) #right=False to not to include the right part of bins in the interval
# Out:
# 0        young
# 1      matured
# 2      matured
# 3      matured
# 4      matured
#         ...
# 886    matured
# 887      young
# 888        NaN
# 889    matured
# 890    matured
# Name: Age, Length: 891, dtype: category
# Categories (3, object): ['young' < 'matured' < 'old']

# %%
df["Fare"]
#create a column if fare < 10 euro the price is cheap, if greater then 10 and less than 25 the price is medium else high
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
def create_flag(x):
    if x < 10:
        return "cheap"
    elif x>=10 and x<25:
        return "medium"
    else:
        return "high"


df['flag_fare'] = df['Fare'].apply(create_flag)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data = {"a": [1, 2, 3, 4],
       "b": [5, 5, 6, 7],
       "c": ["cc", "aj", "cj", "kf"]}
df1 = pd.DataFrame(data)

# %%
df1
# Out:
#    a  b   c
# 0  1  5  cc
# 1  2  5  aj
# 2  3  6  cj
# 3  4  7  kf

# %%
df1.set_index('c', inplace=True)

# %%
df1
# Out:
#     a  b
# c
# cc  1  5
# aj  2  5
# cj  3  6
# kf  4  7

# %%
df1.reset_index(drop = True, inplace=True)

# %%
df1
# Out:
#    a  b
# 0  1  5
# 1  2  5
# 2  3  6
# 3  4  7

# %%
df1.reindex([3, 0, 1, 2]) #if index doesnt exist it will be put null value
# Out:
#    a  b
# 3  4  7
# 0  1  5
# 1  2  5
# 2  3  6

# %%
df1
# Out:
#    a  b
# 0  1  5
# 1  2  5
# 2  3  6
# 3  4  7

# %%
def func(x):
    return x.sum()

# %%
df1
# Out:
#    a  b
# 0  1  5
# 1  2  5
# 2  3  6
# 3  4  7

# %%
df1.apply(func, axis=0) #here sum is happening column wise
# Out:
# a    10
# b    23
# dtype: int64

# %%
df1.apply(func, axis=1) #row wise
# Out:
# 0     6
# 1     7
# 2     9
# 3    11
# dtype: int64

# %%
#apply a function in all the rows and columns
df1.applymap(lambda x: x**2)
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_23744\3290578287.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df1.applymap(lambda x: x**2)
#     a   b
# 0   1  25
# 1   4  25
# 2   9  36
# 3  16  49

# %%
#iterate through datframe
df1
# Out:
#    a  b
# 0  1  5
# 1  2  5
# 2  3  6
# 3  4  7

# %%
#row wise iteration
for i in df1.iterrows():
    print(i,  "------")
# Out:
# (0, a    1
# b    5
# Name: 0, dtype: int64) ------
# (1, a    2
# b    5
# Name: 1, dtype: int64) ------
# (2, a    3
# b    6
# Name: 2, dtype: int64) ------
# (3, a    4
# b    7
# Name: 3, dtype: int64) ------

# %%
#column wise iteration
for i in df1.items():
    print(i,  "------")
# Out:
# ('a', 0    1
# 1    2
# 2    3
# 3    4
# Name: a, dtype: int64) ------
# ('b', 0    5
# 1    5
# 2    6
# 3    7
# Name: b, dtype: int64) ------

# %%
#industry use case
#iteration of a dataframe is not suggested. 
#1. The dataframe if having large no of rows and columns becomes complex to do the computation
#2. It will take more memory space and it will slow
#3. We have better vector computation alternatives like apply, applymap
